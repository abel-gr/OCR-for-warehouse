# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
fig=np.ones((20,20),np.uint8)
x=20
y=20

# %%
abc_min=['a','b','c','ç','d','e','f','g','h','i','j','k','l','m','n','ñ','o','p','q','r','s','t','u','v','w','x','y','z']
abc_maj=['A','B','C','Ç','D','E','F','G','H','I','J','K','L','M','N','Ñ','O','P','Q','R','S','T','U','V','W','X','Y','Z']
num=['1','2','3','4','5','6','7','8','9']

# %%
x2=0.6*x
y2=0.6*y
a= 10
b= 10

for abc in abc_min:
    plt.figure()
    plt.imshow(fig, cmap='gray',vmin=0,vmax=1)
    frame = plt.text(a, b, abc, size=300, ha="center", va="center",fontfamily="BJDS")
    plt.axis('off')
    plt.savefig('cinquena'+str(abc)+'.png')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys

# %%
for abc in abc_maj:
    plt.figure()
    plt.imshow(fig, cmap='gray',vmin=0,vmax=1)
    frame = plt.text(a, b, abc, size=300, ha="center", va="center",fontfamily="hdiw")
    plt.axis('off')
    plt.savefig('cinquena'+str(abc)+'Maj.png')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
for n in num:
    plt.figure()
    plt.imshow(fig, cmap='gray',vmin=0,vmax=1)
    frame = plt.text(a, b, n, size=300, ha="center", va="center",fontfamily="dww")
    plt.axis('off')
    plt.savefig('cinquena'+str(n)+'.png')
