# %% [markdown]
# # Labeling regions experiments

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
img = np.zeros((100, 100))
img[20:25, 3:50] = 1
img[25:65, 20:30] = 1
img[20:25, 70:72] = 1
img[66:70, 40:42] = 1
img[80:90, 44:60] = 1
img[65:85, 80:85] = 1
img[60:67, 80:88] = 1
img[85:95, 25:28] = 1
img[40:45, 77:81] = 1
img[30:42, 77:84] = 1

plt.figure()
plt.imshow(img, cmap="gray")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import LabelingRegions as LabelingRegions

[im_out, eq] = LabelingRegions.LabelingRegionsC8(img)

# %%
plt.figure()
plt.imshow(im_out)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
